# %%
# 1. Define a list called products that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]

type(products)
# Out:
# list

# %%
# 2. Create an empty dictionary called inventory.

# %%
inventory = {}
type(inventory)
# Out:
# dict

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]

inventory = {}

for product in products:
    quantity = int(input("Enter the quantity: " +  product))
    inventory[product] = quantity

print(inventory)
# Out:
# {'t-shirt': 3, 'mug': 4, 'hat': 6, 'book': 5, 'keychain': 4}

# %%
# 4. Create Empty Set

# %%
customer_orders = set()
type(customer_orders)
# Out:
# set

# %%
customer_orders = set()

first_product = str(input("Enter product name: "))
second_product = str(input("Enter product name: "))
third_product = str(input("Enter product name: "))

customer_orders.add(first_product)
customer_orders.add(second_product)
customer_orders.add(third_product)

print(customer_orders)
# Out:
# {'book', 'mug', 'hat'}

# %%
# Total Products Ordered: The total number of products in the customer_orders set.

# %%
total_ordered = len(customer_orders)
print(total_ordered)
# Out:
# 3

# %%
percentage_ordered = (len(products) / total_ordered) * 100

order_status = ( total_ordered, percentage_ordered)

print(order_status)
# Out:
# (3, 166.66666666666669)

# %%
# get percentage and order number
print("Total products ordered: ", total_ordered)
print("Percentage of Products Ordered:", percentage_ordered)
# Out:
# Total products ordered:  3
# Percentage of Products Ordered: 166.66666666666669

# %%
print("\nOrder Statistics:")
print(f"Total Products Ordered: {order_status[0]}")
print(f"Percentage of Products Ordered: {order_status[1]}%")
# Out:
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 166.66666666666669%

# %%
for product in inventory:
    if inventory[product] > 0:
        inventory[product] -= 1

# %%
print(inventory)
# Out:
# {'t-shirt': 2, 'mug': 3, 'hat': 5, 'book': 4, 'keychain': 3}

# %%
print("product and quantity list: \n")
for product, quantity in inventory.items():
    print(f" {product} : {quantity}")
# Out:
# product and quantity list:
#
#  t-shirt : 2
#  mug : 3
#  hat : 5
#  book : 4
#  keychain : 3
